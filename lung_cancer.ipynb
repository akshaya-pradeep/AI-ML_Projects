# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/survey lung cancer.csv')
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
df.tail()
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 304         2                    2                      2           1
# ...

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df.dtypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL CONSUMING         int64
# COUGHING                  int64
# SHORTNESS OF BREATH       int64
# SWALLOWING DIFFICULTY     int64
# CHEST PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['GENDER']=le.fit_transform(df['GENDER'])
df['GENDER']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 304    0
# 305    1
# 306    1
# 307    1
# 308    1
# Name: GENDER, Length: 309, dtype: int64

# %% [markdown]
# In this code, you're using the LabelEncoder from scikit-learn to transform a categorical column ('GENDER') in the dataframe df into a numeric format.
#
# Here's a breakdown of each part:
#
# python
# Copy code
# from sklearn.preprocessing import LabelEncoder
# This imports the LabelEncoder class from scikit-learn, which is used to convert categorical labels (like "Male" and "Female") into numeric codes (like 0 and 1).
#
# python
# Copy code
# le = LabelEncoder()
# This creates an instance of the LabelEncoder class. This instance will be used to fit and transform the 'GENDER' column.
#
# python
# Copy code
# df['GENDER'] = le.fit_transform(df['GENDER'])
# This line does two things:
#
# Fit: The fit() method finds all unique values in df['GENDER'], like "Male" and "Female," and assigns each a unique integer.
# Transform: The transform() method converts each unique category into its corresponding integer code. After transformation, the 'GENDER' column in df will contain numeric values instead of text labels.
# For example:
#
# If the original 'GENDER' column has values ["Male", "Female", "Female", "Male"], LabelEncoder might assign "Male" to 1 and "Female" to 0.
# After transformation, the 'GENDER' column would look like [1, 0, 0, 1].
# This numeric representation is useful because machine learning algorithms often perform better with numeric data than with text-based categories.

# %%
df.isna().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[ 1, 69,  1, ...,  2,  2,  2],
#        [ 1, 74,  2, ...,  2,  2,  2],
#        [ 0, 59,  1, ...,  2,  1,  2],
#        ...,
#        [ 1, 58,  2, ...,  1,  1,  2],
#        [ 1, 67,  2, ...,  2,  1,  2],
#        [ 1, 62,  1, ...,  1,  2,  1]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array(['YES', 'YES', 'NO', 'NO', 'NO', 'YES', 'YES', 'YES', 'NO', 'YES',
#        'YES', 'YES', 'NO', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'NO',
#        'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'NO', 'YES', 'NO',
#        'NO', 'YES', 'NO', 'YES', 'NO', 'YES', 'YES', 'NO', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'NO', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
# array([[ 1, 62,  2, ...,  2,  1,  2],
#        [ 0, 51,  2, ...,  2,  2,  1],
#        [ 1, 67,  1, ...,  2,  1,  2],
#        ...,
#        [ 0, 61,  2, ...,  2,  2,  1],
#        [ 0, 70,  2, ...,  2,  1,  1],
#        [ 1, 64,  2, ...,  2,  1,  2]])

# %%
x_train.shape
# Out:
# (216, 15)

# %%
x_test
# Out:
# array([[ 0, 61,  1, ...,  1,  2,  1],
#        [ 1, 53,  2, ...,  1,  2,  2],
#        [ 1, 73,  1, ...,  2,  2,  2],
#        ...,
#        [ 0, 61,  1, ...,  2,  1,  1],
#        [ 1, 51,  1, ...,  2,  1,  2],
#        [ 0, 73,  2, ...,  2,  2,  2]])

# %%
x_test.shape
# Out:
# (93, 15)

# %%
y_train
# Out:
# array(['YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'NO', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'NO', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES', 'NO',
#        'NO', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES',
#        'YES', 'NO', 'YES', 'YES', 'NO', 'YES', 'NO', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'NO', 'YES', 'NO', 'YES', 'NO', 'YES', 'YES',
# ...

# %%
y_test
# Out:
# array(['YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'NO', 'NO', 'NO', 'YES', 'YES', 'YES', 'YES', 'NO', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'NO',
#        'YES', 'YES'], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.9459053 , -0.04593177,  0.84515425, ...,  0.74428277,
#         -0.88607221,  0.91132238],
#        [-1.05718828, -1.52071397,  0.84515425, ...,  0.74428277,
#          1.12857619, -1.09730654],
#        [ 0.9459053 ,  0.62442378, -1.18321596, ...,  0.74428277,
#         -0.88607221,  0.91132238],
#        ...,
#        [-1.05718828, -0.18000288,  0.84515425, ...,  0.74428277,
#          1.12857619, -1.09730654],
#        [-1.05718828,  1.02663711,  0.84515425, ...,  0.74428277,
#         -0.88607221, -1.09730654],
#        [ 0.9459053 ,  0.22221045,  0.84515425, ...,  0.74428277,
#         -0.88607221,  0.91132238]])

# %%
x_test
# Out:
# array([[-1.05718828, -0.18000288, -1.18321596, ..., -1.34357538,
#          1.12857619, -1.09730654],
#        [ 0.9459053 , -1.25257175,  0.84515425, ..., -1.34357538,
#          1.12857619,  0.91132238],
#        [ 0.9459053 ,  1.42885043, -1.18321596, ...,  0.74428277,
#          1.12857619,  0.91132238],
#        ...,
#        [-1.05718828, -0.18000288, -1.18321596, ...,  0.74428277,
#         -0.88607221, -1.09730654],
#        [ 0.9459053 , -1.52071397, -1.18321596, ...,  0.74428277,
#         -0.88607221,  0.91132238],
#        [-1.05718828,  1.42885043,  0.84515425, ...,  0.74428277,
#          1.12857619,  0.91132238]])

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=7)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'NO', 'YES', 'YES',
#        'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'NO', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'NO',
#        'YES', 'YES'], dtype=object)

# %%
y_test
# Out:
# array(['YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'NO', 'NO', 'NO', 'YES', 'YES', 'YES', 'YES', 'NO', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'NO',
#        'YES', 'YES'], dtype=object)

# %%
print(model.predict(scaler.transform([[1,2,1,3,2,3,1,2,3,4,3,2,1,3,2]])))
# Out:
# ['YES']

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[ 4,  3],
#        [ 2, 84]])

# %%
from sklearn.metrics import accuracy_score
acc_score=accuracy_score(y_test,y_pred)
acc_score
# Out:
# 0.946236559139785
