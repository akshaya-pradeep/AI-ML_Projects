# %% [markdown]
# There are datasets available inside seaborn for study purpose

# %%
import seaborn as sns
df=sns.load_dataset('tips')
df
# tip is the o/p ie to be predicted
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# ## Correlation
#
# - How one column is related with another column.
# - Is it increasing or decresing wrt another column.
# - correlation can be calculated only for numerical columns.
# - Correlation between same column is always highest ie 1.
# - There can be -ve and +ve correlation.

# %%
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# ##Joint plot
#
# - Joint plot is used for numerical columns
#
# - Its just like the scatter plot.
#
# - But along the scatter plot it will generate the histogram also **bold text**

# %%
sns.jointplot(x='tip',y='total_bill',data=df)

# %%
sns.jointplot(x='tip',y='size',data=df)

# %% [markdown]
# - To plot the regression line also
#
# - use kind='reg'
#
# - kind='hex' --> hexagonal shape, by analysing the color intensity we can identify the regresssion line

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %% [markdown]
# ## Pair Plot
# - It is also used for numerical columns.
# - Scatter plot of correlation.
# - The graph of same columns will be formed as histogram.

# %%
sns.pairplot(df)

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %% [markdown]
# we can plot the count in the pair plot
#
# by using hue keyword

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.pairplot(df,hue='day')

# %%
sns.pairplot(df,hue='time')

# %% [markdown]
# # Count Plot
#
# - Used to plot object columns.

# %%
sns.countplot(x='sex',data=df,color='r')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df,color='k')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='day',data=df,color='m')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='time',data=df,color='c')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %% [markdown]
# We can use hue along with this to find how many females and males are smoker and not and so on.

# %%
sns.countplot(x='sex',data=df,color='r',hue='smoker')
# Out:
# <ipython-input-27-9c8c211a78f4>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:r'` for the same effect.
#
#   sns.countplot(x='sex',data=df,color='r',hue='smoker')
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='day',data=df,color='r',hue='time')
# Out:
# <ipython-input-28-80bab6240568>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:r'` for the same effect.
#
#   sns.countplot(x='day',data=df,color='r',hue='time')
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# ## Bar Plot
#
# - When plotting bar plot there will be one numerical and one object

# %%
sns.barplot(x='total_bill',y='day',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.barplot(x='total_bill',y='sex',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.barplot(x='total_bill',y='smoker',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='smoker'>

# %%
sns.barplot(x='total_bill',y='time',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='time'>

# %% [markdown]
# # Box Plot
#
# - To find/identify outliers (wrong datas) box plot is used.

# %%
sns.boxplot(x='smoker',y='total_bill',data=df,color='m')
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %% [markdown]
# circles are the outliers.
#
# Rest in note
#
# Suppose we have datas 3,5,7,1,1,8,4,6
#
# → First sort the datas
#
# 1,1,3,4,      5,6,7,8
#
# → Calculate the median
#
# Median = (4+5)/2 = 4.5 ⇒ Q2 = 4.5
#
# → Calculate the median of 1st part
#
# Median = (1+3)/2 = 2 ⇒ Q1 =2
#
# → Calculate the median of 2nd part
#
# Median = (6+7)/2 = 6.5 ⇒ Q3
#
# → Calculate **IQR (Inter Quartile Range)**
#
# IQR = Q3 - Q1  ⇒  6.5 - 2 = 4.5
#
# —> Outliers can be seen in top and botto,
#
# → Calculate Top Outliers = (1.5xIQR+Q3)  = 13.25
#
# - Ie if a value comes above 13.25 it will be considered as outliers.
#
# → Calculate Bottom Outliers = (Q1-.1.5xIQR)  =  -4.75
#
# - Values that comes below -4.75 are considered as bottom outliers.

# %%
sns.boxplot(y='total_bill',data=df)
# Out:
# <Axes: ylabel='total_bill'>

# %%
import matplotlib.pyplot as plt
def removal_box_plot(df,column,threshold):
  sns.boxplot(df[column])
  plt.title(f"Original box plot of {column}")
  plt.show()

  removed_outliers=df[df[column] >= threshold]

  sns.boxplot(removed_outliers[column])
  plt.title(f'Box Plot Without Outliers of {column}')
  plt.show()
  return removed_outliers

threshold_value=40

no_outliers = removal_box_plot(df,'total_bill',threshold_value)

# %% [markdown]
# Without plotting box plot we can find outliers as

# %%
import numpy as np
Q1 = np.percentile(df['total_bill'],25,method='midpoint') #25 Q1
Q3 = np.percentile(df['total_bill'],75,method='midpoint') # 75 Quarter3
IQR = Q3 - Q1
print(IQR)
# Out:
# 10.849999999999998

# %%
upper = Q3 + 1.5 * IQR
upper_array = np.array(df['total_bill'] >= upper)
print("Upper Bound = ",upper)
print("No.of outliers = ",upper_array.sum())

# BElow lower bound
lower = Q1 - 1.5 * IQR
lower_array = np.array(df['total_bill'] <= lower)
print("lower Bound = ",lower)
print("No.of outliers = ",lower_array.sum())
# Out:
# Upper Bound =  40.449999999999996
# No.of outliers =  9
# lower Bound =  -2.9499999999999993
# No.of outliers =  0
