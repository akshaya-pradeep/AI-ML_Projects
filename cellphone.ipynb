# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/Cellphone.csv')
df
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0           203   2357    10   135.0         5.20  424         8     1.350
# 1           880   1749    10   125.0         4.00  233         2     1.300
# 2            40   1916    10   110.0         4.70  312         4     1.200
# 3            99   1315    11   118.5         4.00  233         2     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# ..          ...    ...   ...     ...          ...  ...       ...       ...
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0            16.0  3.000    13.00        8.0     2610        7.4
# 1             4.0  1.000     3.15        0.0     1700        9.9
# 2             8.0  1.500    13.00        5.0     2000        7.6
# 3             4.0  0.512     3.15        0.0     1400       11.0
# 4             4.0  1.000     3.15        0.0     1700        9.9
# ..            ...    ...      ...        ...      ...        ...
# 156         128.0  6.000    12.00       16.0     4080        8.4
# 157         128.0  6.000    20.00        8.0     3400        7.9
# 158          64.0  4.000    20.00       20.0     3000        6.8
# 159         128.0  6.000    20.00        8.0     3400        7.9
# 160          16.0  3.000    21.50       16.0     2700        8.4
#
# [161 rows x 14 columns]

# %%
df.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
df.tail()
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem  ram  RearCam  Front_Cam  battery  thickness
# 156         128.0  6.0     12.0       16.0     4080        8.4
# 157         128.0  6.0     20.0        8.0     3400        7.9
# 158          64.0  4.0     20.0       20.0     3000        6.8
# 159         128.0  6.0     20.0        8.0     3400        7.9
# 160          16.0  3.0     21.5       16.0     2700        8.4

# %%
df.columns
# Out:
# Index(['Product_id', 'Price', 'Sale', 'weight', 'resoloution', 'ppi',
#        'cpu core', 'cpu freq', 'internal mem', 'ram', 'RearCam', 'Front_Cam',
#        'battery', 'thickness'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Product_id        int64
# Price             int64
# Sale              int64
# weight          float64
# resoloution     float64
# ppi               int64
# cpu core          int64
# cpu freq        float64
# internal mem    float64
# ram             float64
# RearCam         float64
# Front_Cam       float64
# battery           int64
# thickness       float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
x=df.drop(['Product_id','Price'],axis=1)
x
# Out:
#      Sale  weight  resoloution  ppi  cpu core  cpu freq  internal mem    ram  \
# 0      10   135.0         5.20  424         8     1.350          16.0  3.000
# 1      10   125.0         4.00  233         2     1.300           4.0  1.000
# 2      10   110.0         4.70  312         4     1.200           8.0  1.500
# 3      11   118.5         4.00  233         2     1.300           4.0  0.512
# 4      11   125.0         4.00  233         2     1.300           4.0  1.000
# ..    ...     ...          ...  ...       ...       ...           ...    ...
# 156  4638   178.0         5.46  538         4     1.875         128.0  6.000
# 157  8016   170.0         5.50  534         4     1.975         128.0  6.000
# 158  8809   150.0         5.50  401         8     2.200          64.0  4.000
# 159  8946   170.0         5.50  534         4     1.975         128.0  6.000
# 160  9807   202.0         6.00  367         8     1.500          16.0  3.000
#
#      RearCam  Front_Cam  battery  thickness
# 0      13.00        8.0     2610        7.4
# 1       3.15        0.0     1700        9.9
# 2      13.00        5.0     2000        7.6
# 3       3.15        0.0     1400       11.0
# 4       3.15        0.0     1700        9.9
# ..       ...        ...      ...        ...
# 156    12.00       16.0     4080        8.4
# 157    20.00        8.0     3400        7.9
# 158    20.00       20.0     3000        6.8
# 159    20.00        8.0     3400        7.9
# 160    21.50       16.0     2700        8.4
#
# [161 rows x 12 columns]

# %%
y=df['Price']
y
# Out:
# 0      2357
# 1      1749
# 2      1916
# 3      1315
# 4      1749
#        ...
# 156    3551
# 157    3211
# 158    3260
# 159    3211
# 160    2536
# Name: Price, Length: 161, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
#      Sale  weight  resoloution  ppi  cpu core  cpu freq  internal mem  ram  \
# 67     82   310.0          8.0  283         8      2.00           8.0  2.0
# 114   309   145.0          5.1  432         8      2.10          32.0  4.0
# 11     16   161.0          5.5  200         8      1.40           4.0  1.0
# 65     73   175.0          5.5  401         6      1.53          32.0  3.0
# 85    114   279.0          7.0  170         4      1.20           4.0  1.0
# ..    ...     ...          ...  ...       ...       ...           ...  ...
# 71     91   116.0          5.0  294         8      1.50          16.0  2.0
# 106   214   142.0          5.0  440         8      1.25          16.0  2.0
# 14     16   145.0          5.1  432         4      2.50          16.0  2.0
# 92    156   154.0          5.0  294         4      1.20           8.0  1.0
# 102   204   160.0          5.0  220         2      1.20           0.0  1.0
#
#      RearCam  Front_Cam  battery  thickness
# 67       5.0        2.0     4060        7.3
# 114     20.0        8.0     3200        7.0
# 11       5.0        0.0     2500        8.9
# 65      21.0        8.0     3500        9.3
# 85       3.0        0.0     3240        9.0
# ..       ...        ...      ...        ...
# 71      13.0        5.0     2300        7.8
# 106     16.0        8.0     2700        8.0
# 14      16.0        2.0     2800        8.1
# 92      13.0        5.0     2100        8.4
# 102      8.0        0.0     2500       10.8
#
# [112 rows x 12 columns]

# %%
x_test
# Out:
#      Sale  weight  resoloution  ppi  cpu core  cpu freq  internal mem    ram  \
# 105   213    78.4         2.40  166         0     0.000           0.0  0.008
# 108   268   150.0         5.00  294         4     1.200          16.0  1.000
# 142  1530   152.0         5.20  424         4     2.500          16.0  3.000
# 55     45   174.0         5.50  178         4     1.300           4.0  0.512
# 94    164   134.0         4.50  221         4     1.200           8.0  0.512
# 29     26   118.0         5.00  187         4     1.300           8.0  1.000
# 101   201    78.4         2.40  166         0     0.000           0.0  0.008
# 51     43   260.0         7.00  170         2     1.300           4.0  0.512
# 100   198   158.0         5.10  432         4     2.500          16.0  2.000
# 143  1584   152.0         5.20  424         4     2.500          16.0  3.000
# 19     20   134.1         4.00  233         2     1.200           8.0  1.000
# 84    113   404.0         8.00  160         4     1.200           8.0  1.000
# 15     17   141.0         5.00  294         4     1.200           8.0  1.500
# 66     75   158.0         5.50  401         4     1.830          64.0  4.000
# 24     24   139.2         4.70  469         4     2.150          16.0  2.000
# 30     26   150.0         5.00  441         4     2.300          16.0  2.000
# 128   456   753.0        12.20  247         8     1.600          32.0  3.000
# 148  2106   158.0         5.50  401         4     1.875          64.0  6.000
# 98    187   160.0         5.00  220         2     1.200           0.0  1.000
# 16     17   150.0         5.00  441         4     2.300          16.0  2.000
# 75     98   116.0         5.00  294         8     1.500          16.0  2.000
# 18     19   141.0         5.00  294         4     1.200           8.0  1.500
# 12     16   140.0         5.00  294         4     1.300          16.0  1.000
# 9      15   145.0         5.10  432         4     2.500          16.0  2.000
# 31     26   152.0         5.10  577         8     2.300          32.0  4.000
# 152  3248   238.0         5.70  515         8     1.950         128.0  6.000
# 97    179   187.0         6.00  367         8     1.700          16.0  2.000
# 56     52   168.0         5.15  428         8     2.450          64.0  6.000
# 132   567   154.0         5.50  534         4     2.700          32.0  3.000
# 104   208   142.0         5.00  440         8     1.250          16.0  2.000
# 137   996   153.0         5.50  401         8     1.500          64.0  4.000
# 78    101   156.0         5.50  401         8     1.350          16.0  2.000
# 60     58   175.0         5.50  401         6     1.530          32.0  3.000
# 115   309   174.0         5.70  513         4     1.875          32.0  4.000
# 2      10   110.0         4.70  312         4     1.200           8.0  1.500
# 123   399   194.8         5.70  258         4     1.200          16.0  2.000
# 45     40   131.0         5.00  294         4     1.300          16.0  2.000
# 42     38   133.5         4.50  218         4     1.300           8.0  1.000
# 69     87    97.0         4.80  306         8     1.700          16.0  1.000
# 90    141   404.0         8.00  160         4     1.200           8.0  1.000
# 26     24   161.0         5.50  200         8     1.400           4.0  1.000
# 139  1043   160.0         5.00  441         4     2.300          32.0  2.000
# 82    109   171.0         5.70  515         8     1.800          32.0  4.000
# 96    178   187.0         6.00  367         8     1.700          16.0  2.000
# 131   564   165.0         4.66  200         4     1.200           0.0  0.000
# 36     34   139.2         4.70  469         4     2.150          16.0  2.000
# 81    106    66.0         1.50  121         1     0.208           0.0  0.004
# 22     22   152.0         5.10  577         8     2.300          32.0  4.000
# 144  1781   179.0         6.00  184         4     1.300           8.0  1.000
#
#      RearCam  Front_Cam  battery  thickness
# 105      0.0        0.0     1100       12.9
# 108     10.0        0.9     2200        8.5
# 142     20.7        2.2     3100        7.3
# 55       5.0        0.0     2250        9.2
# 94       5.0        0.0     1830        9.2
# 29       8.0        2.0     2000        6.4
# 101      0.0        0.0     1100       12.9
# 51       2.0        0.0     2820        9.1
# 100     16.0        2.0     2800        8.9
# 143     20.7        2.2     3100        7.3
# 19       2.0        0.0     1560       11.7
# 84       5.0        5.0     4500        9.0
# 15       8.0        1.2     2040       10.0
# 66      13.0        5.0     4000        8.5
# 24      16.0        4.0     2200       10.3
# 30      13.0        2.0     2300       10.0
# 128      8.0        2.0     9500        8.0
# 148     16.0        8.0     3000        7.4
# 98       8.0        0.0     2500       10.8
# 16      13.0        2.0     2300       10.0
# 75      13.0        5.0     2300        7.8
# 18       8.0        1.2     2040       10.0
# 12      13.0        5.0     2000        8.2
# 9       16.0        2.0     2800        8.1
# 31      12.0        5.0     3000        7.9
# 152     12.0        8.0     7000        7.4
# 97      13.0       13.0     2930        8.2
# 56      12.0        8.0     3350        7.5
# 132     13.0        2.1     3000        9.1
# 104     16.0        8.0     2700        8.0
# 137     13.0       16.0     3200        7.3
# 78      13.0        5.0     2300        5.1
# 60      21.0        8.0     3500        9.3
# 115     16.0        5.0     3200        7.6
# 2       13.0        5.0     2000        7.6
# 123      8.0        1.0     3400       10.2
# 45      13.0        5.0     2500        8.7
# 42       5.0        0.0     1600       10.1
# 69       8.0        5.0     2100        5.1
# 90       5.0        5.0     4500        9.0
# 26       5.0        0.0     2500        8.9
# 139      4.0        5.0     2600        9.4
# 82      16.0        5.0     3000        7.6
# 96      13.0       13.0     2930        8.2
# 131      5.0        0.0     2600       11.6
# 36      16.0        4.0     2200       10.3
# 81       0.0        0.0      800       13.2
# 22      12.0        5.0     3000        7.9
# 144     13.0        8.0     2580        8.0

# %%
y_train
# Out:
# 67     2044
# 114    2880
# 11     2006
# 65     2824
# 85     1396
#        ...
# 71     2276
# 106    2744
# 14     2580
# 92     1831
# 102    1522
# Name: Price, Length: 112, dtype: int64

# %%
y_test
# Out:
# 105     833
# 108    1676
# 142    2508
# 55     1777
# 94     1511
# 29     1950
# 101     833
# 51     1347
# 100    2343
# 143    2508
# 19     1238
# 84     1646
# 15     1612
# 66     2746
# 24     1942
# 30     2258
# 128    2491
# 148    3055
# 98     1522
# 16     2258
# 75     2276
# 18     1612
# 12     2174
# 9      2580
# 31     2977
# 152    4361
# 97     2562
# 56     3658
# 132    2466
# 104    2744
# 137    3116
# 78     2714
# 60     2824
# 115    2858
# 2      1916
# 123    2001
# 45     1989
# 42     1843
# 69     2323
# 90     1646
# 26     2006
# 139    2409
# 82     3005
# 96     2562
# 131    1357
# 36     1942
# 81      791
# 22     2977
# 144    1921
# Name: Price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 899.21905669, 1865.8018963 , 2628.56815836, 1506.3810264 ,
#        1614.46133409, 1852.82915599,  899.47246267, 1303.3169097 ,
#        2398.19755811, 2627.42783148, 1394.12226803, 1602.82814555,
#        1732.11034516, 2866.26078059, 2266.83076127, 2230.65374919,
#        2515.51576236, 3016.35998654, 1439.74223967, 2230.84380368,
#        2320.30199929, 1732.06811084, 1932.75150888, 2463.39634251,
#        3117.50347114, 4148.21011223, 2439.92861692, 3429.42483309,
#        2678.4509844 , 2520.34587361, 3069.5689513 , 2571.80586926,
#        2581.33018323, 2779.26210015, 2018.38401302, 1852.39345474,
#        2051.44058649, 1578.17977476, 2449.42077761, 1602.23686495,
#        1843.26295536, 2362.51580831, 2943.6369355 , 2439.94973408,
#        1384.27881237, 2266.61958962,  965.18279702, 3117.5879398 ,
#        1728.57935353])

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
print('MAPE = ',mean_absolute_percentage_error(y_test,y_pred))
print('R2_score = ',r2_score(y_test,y_pred))
# Out:
# MAPE =  0.06418770522679626
# R2_score =  0.9539561704745607

# %%
import seaborn as sns
columns = x.columns
j=0
colour = ['r','b','c','k','m','r','c','b','c','k','m','k']
for i in columns:
  sns.regplot(x=df[i],y=y,color=colour[j])
  j+=1
  plt.show()
